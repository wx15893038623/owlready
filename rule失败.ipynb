# %%
from owlready2 import *

onto = get_ontology("http://test.org/onto")
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
with onto:
    class Error(Thing):pass
    class appeared_at(Error >> datetime.datetime): pass
    class TimeRangeWithError(Thing):pass
    class timerange_start_at(TimeRangeWithError >> datetime.datetime, FunctionalProperty): pass
    class timerange_end_at(TimeRangeWithError >> datetime.datetime, FunctionalProperty): pass
    class error_at(TimeRangeWithError >> ConstrainedDatatype(int, min_inclusive = timerange_start_at, max_inclusive = timerange_end_at), FunctionalProperty): pass
    class is_during_timerange(TimeRangeWithError >> bool, FunctionalProperty) : pass
    class TimeRangeRelatedError(Error):
        equivalent_to = [Error & is_during_timerange]

    rule = Imp()
    rule.set_as_rule("""TimeRangeWithError(?d), timerange_start_at(?d, ?s), timerange_end_at(?d, ?e), error_at(?d, ?b), lessThanOrEqual(?b, ?s, ?r1), greaterThanOrEqual(?b, ?e, ?r2), equal(?r1, ?r2, ?r4) -> is_during_timerange(?d, ?r4)""")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-2-04a78acdc324> in <module>()
#       5     class timerange_start_at(TimeRangeWithError >> datetime.datetime, FunctionalProperty): pass
#       6     class timerange_end_at(TimeRangeWithError >> datetime.datetime, FunctionalProperty): pass
# ----> 7     class error_at(TimeRangeWithError >> ConstrainedDatatype(int, min_inclusive = timerange_start_at, max_inclusive = timerange_end_at), FunctionalProperty): pass
#       8     class is_during_timerange(TimeRangeWithError >> bool, FunctionalProperty) : pass
#       9     class TimeRangeRelatedError(Error):
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\prop.py in __init__(Prop, name, bases, obj_dict)
#     451
#     452   def __init__(Prop, name, bases, obj_dict):
# --> 453     super().__init__(name, bases, obj_dict)
#     454
#     455     if SymmetricProperty in Prop.is_a:
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\prop.py in __init__(Prop, name, bases, obj_dict)
#     434 class ReasoningPropertyClass(PropertyClass):
#     435   def __init__(Prop, name, bases, obj_dict):
# --> 436     super().__init__(name, bases, obj_dict)
#     437
#     438     if (not Prop.namespace.world is owl_world):
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\prop.py in __init__(Prop, name, bases, obj_dict)
#      94
#      95       if not range is False:
# ---> 96         Prop.range.extend(range)
#      97
#      98       if not inverse_property is False:
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\util.py in extend(self, l)
#      77   def append(self, x):          old = list(self); super().append(x)         ; self._callback(self._obj, old)
#      78   def insert(self, i, x):       old = list(self); super().insert(i, x)      ; self._callback(self._obj, old)
# ---> 79   def extend(self, l):          old = list(self); super().extend(l)         ; self._callback(self._obj, old)
#      80   def remove(self, x):          old = list(self); super().remove(x)         ; self._callback(self._obj, old)
#      81   def __delitem__(self, i):     old = list(self); super().__delitem__(i)    ; self._callback(self._obj, old)
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\prop.py in _range_changed(Prop, old)
#     185       if isinstance(x, Construct): x._set_ontology(None)
#     186     for x in new - old:
# --> 187       if isinstance(x, Construct): x = x._set_ontology_copy_if_needed(Prop.namespace.ontology, Prop.range)
#     188       x2 = _universal_datatype_2_abbrev.get(x) or x.storid
#     189       Prop.namespace.ontology._add_obj_triple_spo(Prop.storid, rdf_range, x2)
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\class_construct.py in _set_ontology_copy_if_needed(self, ontology, l)
#      37
#      38   def _set_ontology_copy_if_needed(self, ontology, l):
# ---> 39     try:   self._set_ontology(ontology)
#      40     except OwlReadySharedBlankNodeError:
#      41       new = self.__deepcopy__()
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\class_construct.py in _set_ontology(self, ontology)
#      51       elif ontology and not self.ontology:
#      52         if self.storid is None: self.storid = ontology.world.new_blank_node()
# ---> 53         self._create_triples(ontology)
#      54       elif ontology and self.ontology:
#      55         raise OwlReadySharedBlankNodeError("A Construct cannot be shared by two ontologies, because it correspond to a RDF blank node. Please create a dupplicate.")
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\class_construct.py in _create_triples(self, ontology)
#     565           value_datatype_abbrev = _universal_datatype_2_abbrev[self.base_datatype]
#     566         bn = ontology.world.new_blank_node()
# --> 567         ontology._set_data_triple_spod(bn, rdfs_name, v, value_datatype_abbrev)
#     568         l.append((bn, None))
#     569     ontology._set_list_as_rdf(self._list_bnode, l)
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\namespace.py in _set_data_triple_spod(self, s, p, o, d)
#     923     #else:   CURRENT_NAMESPACES[-1].ontology._set_data_triple_raw_spod(s, p, o, d)
#     924     l = CURRENT_NAMESPACES.get()
# --> 925     ((l and l[-1].ontology) or self)._set_data_triple_raw_spod(s, p, o, d)
#     926     if _LOG_LEVEL > 1:
#     927       if not s < 0: s = self._unabbreviate(s)
#
# E:\Programs\Anaconda3\lib\site-packages\owlready2\triplelite.py in _set_data_triple_raw_spod(self, s, p, o, d)
#    1198     if (s is None) or (p is None) or (o is None) or (d is None): raise ValueError
#    1199     self.execute("DELETE FROM datas WHERE c=? AND s=? AND p=?", (self.c, s, p,))
# -> 1200     self.execute("INSERT INTO datas VALUES (?, ?, ?, ?, ?)", (self.c, s, p, o, d))
#    1201
#    1202   def _add_data_triple_raw_spod(self, s, p, o, d):
#
# InterfaceError: Error binding parameter 3 - probably unsupported type.

# %%
error = Error()

timeRange = TimeRangeWithError()
timeRange.shift_start_at = datetime.datetime.now()
timeRange.shift_end_at = datetime.datetime.now()
timeRange.error_at = datetime.datetime.now()



onto.save()
